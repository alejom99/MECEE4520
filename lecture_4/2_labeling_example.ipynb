# %% [markdown]
# # Use [docanno](https://doccano.herokuapp.com/) to classify quotes and create training set

# %% [markdown]
# ## Download docanno using docker

# %%
# !docker pull chakkiworks/doccano
# Out:
# Using default tag: latest
# latest: Pulling from chakkiworks/doccano
# Digest: sha256:dc5cd1d8f34fb44a277581bbc1cf26570a4b890789b211012315d59de38f87e4
# Status: Image is up to date for chakkiworks/doccano:latest

# %% [markdown]
# ## Run docanno

# %%
# !docker run -d --name doccano -p 8081:80 chakkiworks/doccano
# Out:
# 7376cb89e0005f783f5be36d30873d69b2751c0d6985356af2b19261d3dba038

# %% [markdown]
# ## Create admin account

# %%
# !docker exec doccano tools/create-admin.sh "admin" "admin@example.com" "password"
# Out:
# /usr/local/lib/python3.6/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)
# /usr/local/lib/python3.6/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)
# Operations to perform:
#   Apply all migrations: admin, auth, contenttypes, server, sessions, social_django
# Running migrations:
#   Applying contenttypes.0001_initial... OK
#   Applying auth.0001_initial... OK
#   Applying admin.0001_initial... OK
#   Applying admin.0002_logentry_remove_auto_add... OK
#   Applying admin.0003_logentry_add_action_flag_choices... OK
#   Applying contenttypes.0002_remove_content_type_name... OK
#   Applying auth.0002_alter_permission_name_max_length... OK
#   Applying auth.0003_alter_user_email_max_length... OK
#   Applying auth.0004_alter_user_username_opts... OK
#   Applying auth.0005_alter_user_last_login_null... OK
#   Applying auth.0006_require_contenttypes_0002... OK
#   Applying auth.0007_alter_validators_add_error_messages... OK
#   Applying auth.0008_alter_user_username_max_length... OK
#   Applying auth.0009_alter_user_last_name_max_length... OK
#   Applying server.0001_initial... OK
#   Applying server.0002_document_metadata... OK
#   Applying server.0003_shortcut... OK
#   Applying sessions.0001_initial... OK
#   Applying social_django.0001_initial... OK
#   Applying social_django.0002_add_related_name... OK
#   Applying social_django.0003_alter_email_max_length... OK
#   Applying social_django.0004_auto_20160423_0400... OK
#   Applying social_django.0005_auto_20160727_2333... OK
#   Applying social_django.0006_partial... OK
#   Applying social_django.0007_code_timestamp... OK
#   Applying social_django.0008_partial_timestamp... OK
# /usr/local/lib/python3.6/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)
# Superuser created successfully.

# %% [markdown]
# ## Open the web interface, login and create project

# %% [markdown]
# Go to <http://127.0.0.1:8081/login/>
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Upload results from previous step
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Create Positive/Negative Labels
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Click Annotate Data and start labeling
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Download data for future use (JSON)
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Review exported data

# %%
# !tail -n 2 ./data/labeling_results.json
# Out:
# {"doc_id": 19, "text": "“A woman is like a tea bag; you never know how strong it is until it's in hot water.”", "labels": ["POSITIVE"], "username": "admin", "metadata": {"author": "Eleanor Roosevelt", "tags": ["misattributed-eleanor-roosevelt"]}}
# {"doc_id": 20, "text": "“A day without sunshine is like, you know, night.”", "labels": ["NEGATIVE"], "username": "admin", "metadata": {"author": "Steve Martin", "tags": ["humor", "obvious", "simile"]}}
